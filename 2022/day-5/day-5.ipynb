# %%
#     [S] [C]         [Z]            
# [F] [J] [P]         [T]     [N]    
# [G] [H] [G] [Q]     [G]     [D]    
# [V] [V] [D] [G] [F] [D]     [V]    
# [R] [B] [F] [N] [N] [Q] [L] [S]    
# [J] [M] [M] [P] [H] [V] [B] [B] [D]
# [L] [P] [H] [D] [L] [F] [D] [J] [L]
# [D] [T] [V] [M] [J] [N] [F] [M] [G]
#  1   2   3   4   5   6   7   8   9 

boardstring = [
  "    [S] [C]         [Z]            ",
  "[F] [J] [P]         [T]     [N]    ",
  "[G] [H] [G] [Q]     [G]     [D]    ",
  "[V] [V] [D] [G] [F] [D]     [V]    ",
  "[R] [B] [F] [N] [N] [Q] [L] [S]    ",
  "[J] [M] [M] [P] [H] [V] [B] [B] [D]",
  "[L] [P] [H] [D] [L] [F] [D] [J] [L]",
  "[D] [T] [V] [M] [J] [N] [F] [M] [G]"
]

def gett(x,y):
  x = 1+(x*4)
  return boardstring[7-y][x]

board = []

for x in range(9):
  col = []
  for y in range(8):
    v = gett(x,y)
    if not v == ' ':
      col.append(gett(x,y))
  board.append(col)

def move(fr,to):
  f = board[fr-1].pop()
  board[to-1].append(f)

print("BOARD")
print(len(board))
[print(b) for b in board]

import re
f = open('input', 'r').readlines()

for line in f:
  r = re.findall(r'[0-9]+', line.strip())
  vals = [int(a) for a in r]
  count = vals[0]
  f = vals[1]
  t = vals[2]

  for _ in range(count): move(f,t)

# for _ in range(3): move(1,9)

print("BOARD")
print(len(board))
[print(b) for b in board]

print("res")
print([b[-1] for b in board])
# Out:
# BOARD
# 9
# ['D', 'L', 'J', 'R', 'V', 'G', 'F']
# ['T', 'P', 'M', 'B', 'V', 'H', 'J', 'S']
# ['V', 'H', 'M', 'F', 'D', 'G', 'P', 'C']
# ['M', 'D', 'P', 'N', 'G', 'Q']
# ['J', 'L', 'H', 'N', 'F']
# ['N', 'F', 'V', 'Q', 'D', 'G', 'T', 'Z']
# ['F', 'D', 'B', 'L']
# ['M', 'J', 'B', 'S', 'V', 'D', 'N']
# ['G', 'L', 'D']
# BOARD
# 9
# ['G', 'Q']
# ['V', 'M']
# ['N', 'B']
# ['M']
# ['J', 'H', 'M', 'T', 'B', 'F', 'S', 'V', 'Z', 'N', 'G', 'D', 'V', 'F', 'V', 'H', 'P', 'D', 'F', 'L', 'H', 'D', 'D', 'S', 'G', 'L', 'J', 'J', 'R', 'L', 'G', 'V', 'J']
# ['D', 'N', 'N', 'D']
# ['F']
# ['T']
# ['Q', 'G', 'P', 'F', 'B', 'C', 'M', 'L', 'P', 'D']
# res
# ['Q', 'M', 'B', 'M', 'J', 'D', 'F', 'T', 'D']

# %%
#     [S] [C]         [Z]            
# [F] [J] [P]         [T]     [N]    
# [G] [H] [G] [Q]     [G]     [D]    
# [V] [V] [D] [G] [F] [D]     [V]    
# [R] [B] [F] [N] [N] [Q] [L] [S]    
# [J] [M] [M] [P] [H] [V] [B] [B] [D]
# [L] [P] [H] [D] [L] [F] [D] [J] [L]
# [D] [T] [V] [M] [J] [N] [F] [M] [G]
#  1   2   3   4   5   6   7   8   9 

boardstring = [
  "    [S] [C]         [Z]            ",
  "[F] [J] [P]         [T]     [N]    ",
  "[G] [H] [G] [Q]     [G]     [D]    ",
  "[V] [V] [D] [G] [F] [D]     [V]    ",
  "[R] [B] [F] [N] [N] [Q] [L] [S]    ",
  "[J] [M] [M] [P] [H] [V] [B] [B] [D]",
  "[L] [P] [H] [D] [L] [F] [D] [J] [L]",
  "[D] [T] [V] [M] [J] [N] [F] [M] [G]"
]

def gett(x,y):
  x = 1+(x*4)
  return boardstring[7-y][x]

board = []

for x in range(9):
  col = []
  for y in range(8):
    v = gett(x,y)
    if not v == ' ':
      col.append(gett(x,y))
  board.append(col)

def move(fr,to,count):
  f = board[fr-1][-count:]
  # f = board[fr-1].pop()
  for v in f: board[to-1].append(v)
  for _ in range(count): board[fr-1].pop()

print("BOARD")
print(len(board))
[print(b) for b in board]

import re
f = open('input', 'r').readlines()

for line in f:
  r = re.findall(r'[0-9]+', line.strip())
  vals = [int(a) for a in r]
  count = vals[0]
  f = vals[1]
  t = vals[2]

  move(f,t, count)

# for _ in range(3): move(1,9)

print("BOARD")
print(len(board))
[print(b) for b in board]

print("res")
print([b[-1] for b in board])
# Out:
# BOARD
# 9
# ['D', 'L', 'J', 'R', 'V', 'G', 'F']
# ['T', 'P', 'M', 'B', 'V', 'H', 'J', 'S']
# ['V', 'H', 'M', 'F', 'D', 'G', 'P', 'C']
# ['M', 'D', 'P', 'N', 'G', 'Q']
# ['J', 'L', 'H', 'N', 'F']
# ['N', 'F', 'V', 'Q', 'D', 'G', 'T', 'Z']
# ['F', 'D', 'B', 'L']
# ['M', 'J', 'B', 'S', 'V', 'D', 'N']
# ['G', 'L', 'D']
# BOARD
# 9
# ['M', 'N']
# ['D', 'B']
# ['R', 'T']
# ['V']
# ['D', 'F', 'G', 'F', 'D', 'G', 'B', 'P', 'N', 'D', 'F', 'D', 'M', 'L', 'V', 'D', 'M', 'G', 'C', 'M', 'S', 'J', 'P', 'P', 'V', 'H', 'D', 'Q', 'G', 'J', 'N', 'G', 'T']
# ['H', 'L', 'L', 'J']
# ['N']
# ['F']
# ['L', 'B', 'V', 'V', 'F', 'Q', 'Z', 'S', 'H', 'J']
# res
# ['N', 'B', 'T', 'V', 'T', 'J', 'N', 'F', 'J']
