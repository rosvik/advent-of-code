# %%
data = "..."


for i, char in enumerate(data):
  co = data[i-4:i]
  if len(set(co)) == 4:
    print(i, co)
# Out:
# 1760 msnw
# 1761 snwc
# 1762 nwcg
# 1763 wcgd
# 1764 cgdf
# 1765 gdfq
# 1766 dfql
# 1767 fqlj
# 1768 qljm
# 1769 ljmn
# 1770 jmnp
# 1771 mnph
# 1772 nphl
# 1773 phlf
# 1774 hlfd
# 1775 lfdr
# 1776 fdrh
# 1777 drhp
# 1778 rhpg
# 1782 gfqn
# 1783 fqnh
# 1786 hnsz
# 1787 nszg
# 1788 szgp
# 1789 zgpn
# 1790 gpnd
# 1791 pndh
# 1794 hdqc
# 1795 dqcg
# 1796 qcgf
# 1797 cgfh
# 1798 gfht
# 1799 fhtd
# 1800 htdc
# 1801 tdcg
# 1802 dcgb
# 1803 cgbs
# 1806 sbtm
# 1807 btmh
# 1808 tmhv
# 1809 mhvn
# 1813 nrmq
# 1814 rmqz
# 1819 qcjd
# 1820 cjdq
# 1821 jdqn
# 1823 qndz
# 1824 ndzb
# 1825 dzbn
# 1826 zbnr
# 1827 bnrh
# 1828 nrhw
# 1829 rhwj
# 1830 hwjv
# 1831 wjvb
# 1834 bvcl
# 1835 vcld
# 1836 cldm
# 1837 ldmn
# 1838 dmnw
# 1839 mnwl
# 1840 nwlt
# 1841 wltg
# 1842 ltgp
# 1843 tgpq
# 1844 gpqb
# 1845 pqbm
# 1846 qbms
# 1847 bmst
# 1848 mstn
# 1855 gtbq
# 1856 tbqj
# 1857 bqjz
# 1861 zqrf
# 1862 qrfd
# 1863 rfds
# 1865 dsft
# 1869 tdfr
# 1870 dfrc
# 1871 frcn
# 1872 rcns
# 1873 cnsr
# 1874 nsrp
# ...

# %%
d = "..."

for i in range(9999):
 if len(set(d[i-14:i]))>13:print(i)
# Out:
# 2974
